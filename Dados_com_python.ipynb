# %% [markdown]
# #Lógica de Programação com Python

# %%
nome = 'Gleisson'

# %%
print(f'Meu nome é {nome}')
# Out:
# Meu nome é Gleisson

# %% [markdown]
# Função sem parametros

# %%
def saudacao():
 nome = input("Qual é o seu nome: ")
 print(f'Olá {nome}')

# %%
saudacao()
# Out:
# Qual é o seu nome: Gleisson
# Olá Gleisson

# %% [markdown]
# # Função com Parametros

# %%
nome = 'Gleisson'

# %%
def saudacao_com_parametro(nome_da_pessoa):
  print(f'Olá {nome_da_pessoa}')

# %%
saudacao_com_parametro(nome)
# Out:
# Olá Gleisson

# %% [markdown]
# # Condicional

# %%
idade = 15

# %%
def ja_pode_dirigir(idade):
  if idade >= 18:
    print("Tem permissão para dirigir")
  else:
    print('Não tem permissão')

# %%
ja_pode_dirigir(idade)
# Out:
# Não tem permissão

# %%
def verifica_se_pode_dirigir_sem_parametros():
 idade = int(input("Qual é a sua idade? "))
 if idade >= 18:
   print("Tem permissão")
 else:
  print("Não tem permissão")

# %%
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Qual é a sua idade? 17
# Não tem permissão

# %% [markdown]
# # Convertendo tipo para inteiro

# %%
def verifica_se_pode_dirigir_sem_parametros():
 idade = int(input("Qual é a sua idade? "))
 if idade >= 18:
   print("Tem permissão")
 else:
  print("Não tem permissão")

# %%
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Qual é a sua idade? 17
# Não tem permissão

# %%
def velocidade(espaco,tempo):
  resultado = espaco/tempo
  print(resultado)

# %%
velocidade(100,20)
# Out:
# 5.0

# %% [markdown]
# # Operadores do Python

# %%
#a == b	a igual a b
#a != b	a diferente de b
#a < b	a menor do que b
#a > b	a maior do que b
#a <= b	a menor ou igual a b
#a >= b	a maior ou igual a b

# %% [markdown]
# # Lista

# %%
idade = 22
idade
# Out:
# 22

# %%
type(idade)
# Out:
# int

# %%
nome = 'gleisson'

# %%
type(nome)
# Out:
# str

# %%
idades = [18, 22, 15, 50]
#sempre que criamos uma lista nossos indices inicia com o 0

# %%
type(idades)
# Out:
# list

# %%
idades[1]
# Out:
# 22

# %%
idades[:3]
# Out:
# [18, 22, 15]

# %%
idades[0:3]
# Out:
# [18, 22, 15]

# %%
idades[-4]
# Out:
# 18

# %% [markdown]
# # Laços e Loops

# %%
#for fora da função
def ja_pode_dirigir(idade):
  if idade >= 18:
    print(f"{idade} anos de idade,TEM permissão para dirigir")
  else:
    print(f'{idade} anos de idade,NÃO TEM permissão')

# %%
idades
# Out:
# [18, 22, 15, 50]

# %%
for idade in idades:
  ja_pode_dirigir(idade)
# Out:
# 18 anos de idade,TEM permissão para dirigir
# 22 anos de idade,TEM permissão para dirigir
# 15 anos de idade,NÃO TEM permissão
# 50 anos de idade,TEM permissão para dirigir

# %%
#for dentro da função
def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >= 18:
      print(f"{idade} anos de idade,TEM permissão para dirigir")
    else:
     print(f'{idade} anos de idade,NÃO TEM permissão')

# %%
verifica_se_pode_dirigir(idades)
# Out:
# 18 anos de idade,TEM permissão para dirigir
# 22 anos de idade,TEM permissão para dirigir
# 15 anos de idade,NÃO TEM permissão
# 50 anos de idade,TEM permissão para dirigir

# %% [markdown]
# # Boleano

# %%
idade = 15
idade >= 18
# Out:
# False

# %%
idade = 18
idade >= 18
# Out:
# True

# %%
permissoes = []
idades = [20, 14, 40]

# %%
def verifica_se_pode_dirigir(idades,permissoes):
  for x in idades:
    if x >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False)

# %%
verifica_se_pode_dirigir(idades,permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for x in permissoes:
  if x == True:
    print("Tem permissão")
  else:
    print('Não tem permissão')
# Out:
# Tem permissão
# Não tem permissão
# Tem permissão

# %% [markdown]
# # Tipos em uma lista

# %%
lista = ['Guilherme', 28, True, '18']

# %%
for x in lista:
  print(f'O elemento {x} é do tipo',type(x))
# Out:
# O elemento Guilherme é do tipo <class 'str'>
# O elemento 28 é do tipo <class 'int'>
# O elemento True é do tipo <class 'bool'>
# O elemento 18 é do tipo <class 'str'>

# %% [markdown]
# # Imports

# %%
from random import randrange, seed

# %%
seed(10)

# %%
randrange(0,11)
# Out:
# 9

# %%
notas_matematicas = []

# %%
for x in range(8):
  notas_matematicas.append(randrange(0,11))
notas_matematicas
# Out:
# [0, 6, 7, 9, 0, 3, 7, 7]

# %%
len(notas_matematicas)
# Out:
# 8

# %% [markdown]
# # **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1,9))
y = notas_matematicas
plt.plot(x, y, marker = 'o')
plt.title('Notas de matematica')
plt.xlabel('Notas')
plt.ylabel('Provas')
plt.show()

# %%
notas_matematicas
# Out:
# [0, 6, 7, 9, 0, 3, 7, 7]
